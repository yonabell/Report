# %% [markdown]
# <a href="https://colab.research.google.com/github/yonabell/Report/blob/main/Max_Quarters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5ed19d9f-34da-449b-8f12-8805857da233" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ed19d9f-34da-449b-8f12-8805857da233">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = r'H:\JXG\JX GR\01 Credit Risk Modelling\Limit Utilization\ZAG-MaRisk\open_items.csv'
output_path = r'H:\JXG\JX GR\01 Credit Risk Modelling\Limit Utilization\ZAG-MaRisk\max_values_transposed.csv'

# %%
# Read the CSV/Excel file content, using the first row as the header
df = pd.read_csv(df, header=0)

# %%
# Function to convert dates to quarters
def date_to_quarter(date_str):
    date = pd.to_datetime(date_str, dayfirst=True)
    quarter = (date.month - 1) // 3 + 1  # Get quarter
    return f"Q{quarter}/{date.year}"  # Format as Qn/yyyy

# %%
#How indexing work for quarters
"""January (1) to March (3) becomes 0 (Q0)
April (4) to June (6) becomes 1 (Q1)
July (7) to September (9) becomes 2 (Q2)
October (10) to December (12) becomes 3 (Q3)
+ 1: Finally, we add 1 to shift the zero-based index to a one-based index, resulting in:
0 becomes 1 (Q1)
1 becomes 2 (Q2)
2 becomes 3 (Q3)
3 becomes 4 (Q4)"""

# %%
# Apply the conversion function
df['Quarter'] = df['Date'].apply(date_to_quarter)

# %%
# Drop the original date column
df = df.drop(columns=['Date'])

# %%
# Move 'Quarter' column to the first position
cols = list(df.columns)
cols.insert(0, cols.pop(cols.index('Quarter')))
df = df[cols]

# %%
# Ensure 'Quarter' column exists and remove non-numeric columns from max calculation
numeric_columns = df.columns[1:]  # Assuming the first column is 'Quarter', and rest are numeric

# %%
# Filter the rows based on the 'Quarter' column
q1_rows = df[df['Quarter'].str.contains("Q1")]
q2_rows = df[df['Quarter'].str.contains("Q2")]
q3_rows = df[df['Quarter'].str.contains("Q3")]
q4_rows = df[df['Quarter'].str.contains("Q4")]

# %%
# Calculate the maximum values for each category in each quarter
max_q1 = q1_rows[numeric_columns].max(axis=0)
max_q2 = q2_rows[numeric_columns].max(axis=0)
max_q3 = q3_rows[numeric_columns].max(axis=0)
max_q4 = q4_rows[numeric_columns].max(axis=0)

# %%
# Combine the max values into a DataFrame
max_values = pd.DataFrame({
    'Max_Q1': max_q1.values,
    'Max_Q2': max_q2.values,
    'Max_Q3': max_q3.values,
    'Max_Q4': max_q4.values
}, index=numeric_columns)

# %%
# Transpose the result so that Max_Q1, Max_Q2, etc. are rows, and categories are columns
max_values_transposed = max_values.T
# Out:
#         EE  MC  CN   KR  MY   PH  TH  CR  GT  NI  ...  SE  SG  SI  SK  TR  US  \
# Max_Q1  88  99  66  220  23   23  23  23  23  23  ...  23  23  23  23  23  23
# Max_Q2  27  27  27   27  27   27  27  27  27  27  ...  27  27  27  27  27  27
# Max_Q3  28  28  28   28  28  777  28  28  28  28  ...  28  28  28  28  28  28
# Max_Q4  29  29  29   29  29   29  29  29  29  29  ...  29  29  29  29  29  29
#
#         Unknown  ZA  CH+LI  Total
# Max_Q1       23  23     23     23
# Max_Q2       27  27     27     27
# Max_Q3       28  28     28     28
# Max_Q4       29  29     29     29
#
# [4 rows x 71 columns]

# %%
# Assuming you have the max_values_transposed DataFrame as calculated before
max_values_transposed.index.name = 'Quarters'
max_values_transposed
# Out:
#           EE  MC  CN   KR  MY   PH  TH  CR  GT  NI  ...  SE  SG  SI  SK  TR  \
# Quarters                                            ...
# Max_Q1    88  99  66  220  23   23  23  23  23  23  ...  23  23  23  23  23
# Max_Q2    27  27  27   27  27   27  27  27  27  27  ...  27  27  27  27  27
# Max_Q3    28  28  28   28  28  777  28  28  28  28  ...  28  28  28  28  28
# Max_Q4    29  29  29   29  29   29  29  29  29  29  ...  29  29  29  29  29
#
#           US  Unknown  ZA  CH+LI  Total
# Quarters
# Max_Q1    23       23  23     23     23
# Max_Q2    27       27  27     27     27
# Max_Q3    28       28  28     28     28
# Max_Q4    29       29  29     29     29
#
# [4 rows x 71 columns]

# %%
# Save the DataFrame to a CSV file
max_values_transposed.to_csv(output_path, index=False)

print(f'DataFrame saved to {output_path}')
